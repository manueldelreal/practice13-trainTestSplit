# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Train-test Split and Cross-Validation Lab
#
# _Authors: Joseph Nelson (DC), Kiefer Katovich (SF)_
#
# ---
#
# ## Review of train/test validation methods
#
# We've discussed overfitting, underfitting, and how to validate the "generalizeability" of your models by testing them on unseen data.
#
# In this lab you'll practice two related validation methods:
# 1. **train/test split**
# 2. **k-fold cross-validation**
#
# Train/test split and k-fold cross-validation both serve two useful purposes:
# - We prevent overfitting by not using all the data, and
# - We retain some remaining data to evaluate our model.
#
# In the case of cross-validation, the model fitting and evaluation is performed multiple times on different train/test splits of the data.
#
# Ultimately we can the training and testing validation framework to compare multiple models on the same dataset. This could be comparisons of two linear models, or of completely different models on the same data.

# %% [markdown]
# ## Instructions
#
# For your independent practice, fit **three different models** on the Boston housing data. For example, you could pick three different subsets of variables, one or more polynomial models, or any other model that you like.
#
# **Start with train/test split validation:**
# * Fix a testing/training split of the data
# * Train each of your models on the training data
# * Evaluate each of the models on the test data
# * Rank the models by how well they score on the testing data set.
#
# **Then try K-Fold cross-validation:**
# * Perform a k-fold cross validation and use the cross-validation scores to compare your models. Did this change your rankings?
# * Try a few different K-splits of the data for the same models.
#
# If you're interested, try a variety of response variables.  We start with **MEDV** (the `.target` attribute from the dataset load method).

# %%
from matplotlib import pyplot as plt

import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns



# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

plt.style.use('fivethirtyeight')

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()
X = pd.DataFrame(housing.data, columns=housing.feature_names)
y = housing.target

# %% [markdown]
# ### 1. Clean up any data problems
#
# Load the California housing data.  Fix any problems, if applicable.

# %%
# A: Switch it up to use the california housing dataset from sklearn as well, it seems to be clean.

# %% [markdown]
# ### 2. Select 3-4 variables with your dataset to perform a 50/50 test train split on
#
# - Use sklearn.
# - Score and plot your predictions.

# %%
X.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

predictors = ['MedInc', 'AveRooms', 'AveBedrms', 'HouseAge']
X_train, X_test, y_train, y_test = train_test_split(X[predictors], y, train_size=0.5, random_state=8)

lr = LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
# Out:
# 0.5399650329502999

# %%
yhat = lr.predict(X_test)
sns.jointplot(y_test, yhat);
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### 3. Try 70/30 and 90/10
# - Score and plot.
# - How do your metrics change?

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = train_test_split(X[predictors], y, train_size=0.7, random_state=8)


lr2 = LinearRegression()
lr2.fit(X_train,y_train)
lr2.score(X_test, y_test)
# Out:
# 0.5346483651379534

# %%
yhat = lr.predict(X_test)
sns.jointplot(y_test, yhat);
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = train_test_split(X[predictors], y, train_size=0.9, random_state=8)


lr2 = LinearRegression()
lr2.fit(X_train,y_train)
lr2.score(X_test, y_test)
# Out:
# 0.5613247667681427

# %%
yhat = lr.predict(X_test)
sns.jointplot(y_test, yhat);
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### 4. Try K-Folds cross-validation with K between 5-10 for your regression.
#
# - What seems optimal?
# - How do your scores change?
# - What the variance of scores like?
# - Try different folds to get a sense of how this impacts your score.

# %%
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn import metrics

# iterate through folds 5-10
for folds in range(5,11):
    print('------------------------------------\n')
    print('K: {}'.format(folds))
    model = LinearRegression()
    
    # Perform cross-validation
    scores = cross_val_score(model, X[predictors], y, cv=folds)
    print("Cross-validated scores: {}".format(scores))
    print("Mean CV R2: {}".format(np.mean(scores)))
    print('Std CV R2: {}'.format(np.std(scores)))
    
    # Make cross-validated predictions
    predictions = cross_val_predict(model, X[predictors], y, cv=folds)
    
    r2 = metrics.r2_score(y, predictions)
    print("Cross-Predicted R2: {}".format(r2))
# Out:
# ------------------------------------
#
# K: 5
# Cross-validated scores: [0.51049072 0.43868013 0.5123008  0.45205045 0.55393208]
# Mean CV R2: 0.4934908372359891
# Std CV R2: 0.042467571722065015
# Cross-Predicted R2: 0.5227616496779672
# ------------------------------------
#
# K: 6
# Cross-validated scores: [0.39639075 0.40402165 0.52379999 0.51013838 0.44954553 0.58144272]
# Mean CV R2: 0.47755650425645074
# Std CV R2: 0.06679852176498875
# Cross-Predicted R2: 0.5184408815949456
# ------------------------------------
#
# K: 7
# Cross-validated scores: [0.46104207 0.4584386  0.54088909 0.48735143 0.28053425 0.36411859
#  0.61329512]
# Mean CV R2: 0.4579527367922157
# Std CV R2: 0.10153530407035938
# Cross-Predicted R2: 0.5202648229905422
# ------------------------------------
#
# K: 8
# Cross-validated scores: [0.50352952 0.46986743 0.50949558 0.50436617 0.53708982 0.4220919
#  0.30419165 0.61363276]
# Mean CV R2: 0.4830331042271645
# Std CV R2: 0.08472403300659036
# Cross-Predicted R2: 0.5249328305333146
# ------------------------------------
#
# K: 9
# Cross-validated scores: [0.51354885 0.50572013 0.44434281 0.47768151 0.54272039 0.25945619
#  0.44659349 0.435823   0.50288914]
# Mean CV R2: 0.45875283472182093
# Std CV R2: 0.07829134960530748
# Cross-Predicted R2: 0.5247936122755947
# ------------------------------------
#
# K: 10
# Cross-validated scores: [0.52885538 0.47729723 0.38676354 0.48210024 0.50662664 0.5014332
#  0.1746162  0.40578634 0.29987913 0.44621443]
# Mean CV R2: 0.42095723238363814
# Std CV R2: 0.10476230285685063
# Cross-Predicted R2: 0.5199600637397322

# %% [markdown]
# ### 5. [Bonus] optimize the $R^2$ score
#
# Can you optimize your R^2 by selecting the best features and validating the model using either train/test split or K-Folds?
#
# Your code will need to iterate through the different combinations of predictors, cross-validate the current model parameterization, and determine which set of features performed best.
#
# The number of K-folds is up to you.
#
# > *Hint:* the `itertools` package is useful for combinations and permutations.

# %%
from itertools import combinations

# %%
combs = []
for i in range(1, len(X.columns)+1):
    for c in combinations(X.columns.tolist(), i):
        combs.append(c)

# %%
combs
# Out:
# [('MedInc',),
#  ('HouseAge',),
#  ('AveRooms',),
#  ('AveBedrms',),
#  ('Population',),
#  ('AveOccup',),
#  ('Latitude',),
#  ('Longitude',),
#  ('MedInc', 'HouseAge'),
#  ('MedInc', 'AveRooms'),
#  ('MedInc', 'AveBedrms'),
#  ('MedInc', 'Population'),
#  ('MedInc', 'AveOccup'),
#  ('MedInc', 'Latitude'),
#  ('MedInc', 'Longitude'),
#  ('HouseAge', 'AveRooms'),
#  ('HouseAge', 'AveBedrms'),
#  ('HouseAge', 'Population'),
#  ('HouseAge', 'AveOccup'),
#  ('HouseAge', 'Latitude'),
#  ('HouseAge', 'Longitude'),
#  ('AveRooms', 'AveBedrms'),
#  ('AveRooms', 'Population'),
#  ('AveRooms', 'AveOccup'),
#  ('AveRooms', 'Latitude'),
#  ('AveRooms', 'Longitude'),
#  ('AveBedrms', 'Population'),
#  ('AveBedrms', 'AveOccup'),
#  ('AveBedrms', 'Latitude'),
#  ('AveBedrms', 'Longitude'),
#  ('Population', 'AveOccup'),
#  ('Population', 'Latitude'),
#  ('Population', 'Longitude'),
#  ('AveOccup', 'Latitude'),
#  ('AveOccup', 'Longitude'),
#  ('Latitude', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveRooms'),
#  ('MedInc', 'HouseAge', 'AveBedrms'),
#  ('MedInc', 'HouseAge', 'Population'),
#  ('MedInc', 'HouseAge', 'AveOccup'),
#  ('MedInc', 'HouseAge', 'Latitude'),
#  ('MedInc', 'HouseAge', 'Longitude'),
#  ('MedInc', 'AveRooms', 'AveBedrms'),
#  ('MedInc', 'AveRooms', 'Population'),
#  ('MedInc', 'AveRooms', 'AveOccup'),
#  ('MedInc', 'AveRooms', 'Latitude'),
#  ('MedInc', 'AveRooms', 'Longitude'),
#  ('MedInc', 'AveBedrms', 'Population'),
#  ('MedInc', 'AveBedrms', 'AveOccup'),
#  ('MedInc', 'AveBedrms', 'Latitude'),
#  ('MedInc', 'AveBedrms', 'Longitude'),
#  ('MedInc', 'Population', 'AveOccup'),
#  ('MedInc', 'Population', 'Latitude'),
#  ('MedInc', 'Population', 'Longitude'),
#  ('MedInc', 'AveOccup', 'Latitude'),
#  ('MedInc', 'AveOccup', 'Longitude'),
#  ('MedInc', 'Latitude', 'Longitude'),
#  ('HouseAge', 'AveRooms', 'AveBedrms'),
#  ('HouseAge', 'AveRooms', 'Population'),
#  ('HouseAge', 'AveRooms', 'AveOccup'),
#  ('HouseAge', 'AveRooms', 'Latitude'),
#  ('HouseAge', 'AveRooms', 'Longitude'),
#  ('HouseAge', 'AveBedrms', 'Population'),
#  ('HouseAge', 'AveBedrms', 'AveOccup'),
#  ('HouseAge', 'AveBedrms', 'Latitude'),
#  ('HouseAge', 'AveBedrms', 'Longitude'),
#  ('HouseAge', 'Population', 'AveOccup'),
#  ('HouseAge', 'Population', 'Latitude'),
#  ('HouseAge', 'Population', 'Longitude'),
#  ('HouseAge', 'AveOccup', 'Latitude'),
#  ('HouseAge', 'AveOccup', 'Longitude'),
#  ('HouseAge', 'Latitude', 'Longitude'),
#  ('AveRooms', 'AveBedrms', 'Population'),
#  ('AveRooms', 'AveBedrms', 'AveOccup'),
#  ('AveRooms', 'AveBedrms', 'Latitude'),
#  ('AveRooms', 'AveBedrms', 'Longitude'),
#  ('AveRooms', 'Population', 'AveOccup'),
#  ('AveRooms', 'Population', 'Latitude'),
#  ('AveRooms', 'Population', 'Longitude'),
#  ('AveRooms', 'AveOccup', 'Latitude'),
#  ('AveRooms', 'AveOccup', 'Longitude'),
#  ('AveRooms', 'Latitude', 'Longitude'),
#  ('AveBedrms', 'Population', 'AveOccup'),
#  ('AveBedrms', 'Population', 'Latitude'),
#  ('AveBedrms', 'Population', 'Longitude'),
#  ('AveBedrms', 'AveOccup', 'Latitude'),
#  ('AveBedrms', 'AveOccup', 'Longitude'),
#  ('AveBedrms', 'Latitude', 'Longitude'),
#  ('Population', 'AveOccup', 'Latitude'),
#  ('Population', 'AveOccup', 'Longitude'),
#  ('Population', 'Latitude', 'Longitude'),
#  ('AveOccup', 'Latitude', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'AveBedrms'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'Population'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'AveOccup'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'Latitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveBedrms', 'Population'),
#  ('MedInc', 'HouseAge', 'AveBedrms', 'AveOccup'),
#  ('MedInc', 'HouseAge', 'AveBedrms', 'Latitude'),
#  ('MedInc', 'HouseAge', 'AveBedrms', 'Longitude'),
#  ('MedInc', 'HouseAge', 'Population', 'AveOccup'),
#  ('MedInc', 'HouseAge', 'Population', 'Latitude'),
#  ('MedInc', 'HouseAge', 'Population', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveOccup', 'Latitude'),
#  ('MedInc', 'HouseAge', 'AveOccup', 'Longitude'),
#  ('MedInc', 'HouseAge', 'Latitude', 'Longitude'),
#  ('MedInc', 'AveRooms', 'AveBedrms', 'Population'),
#  ('MedInc', 'AveRooms', 'AveBedrms', 'AveOccup'),
#  ('MedInc', 'AveRooms', 'AveBedrms', 'Latitude'),
#  ('MedInc', 'AveRooms', 'AveBedrms', 'Longitude'),
#  ('MedInc', 'AveRooms', 'Population', 'AveOccup'),
#  ('MedInc', 'AveRooms', 'Population', 'Latitude'),
#  ('MedInc', 'AveRooms', 'Population', 'Longitude'),
#  ('MedInc', 'AveRooms', 'AveOccup', 'Latitude'),
#  ('MedInc', 'AveRooms', 'AveOccup', 'Longitude'),
#  ('MedInc', 'AveRooms', 'Latitude', 'Longitude'),
#  ('MedInc', 'AveBedrms', 'Population', 'AveOccup'),
#  ('MedInc', 'AveBedrms', 'Population', 'Latitude'),
#  ('MedInc', 'AveBedrms', 'Population', 'Longitude'),
#  ('MedInc', 'AveBedrms', 'AveOccup', 'Latitude'),
#  ('MedInc', 'AveBedrms', 'AveOccup', 'Longitude'),
#  ('MedInc', 'AveBedrms', 'Latitude', 'Longitude'),
#  ('MedInc', 'Population', 'AveOccup', 'Latitude'),
#  ('MedInc', 'Population', 'AveOccup', 'Longitude'),
#  ('MedInc', 'Population', 'Latitude', 'Longitude'),
#  ('MedInc', 'AveOccup', 'Latitude', 'Longitude'),
#  ('HouseAge', 'AveRooms', 'AveBedrms', 'Population'),
#  ('HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup'),
#  ('HouseAge', 'AveRooms', 'AveBedrms', 'Latitude'),
#  ('HouseAge', 'AveRooms', 'AveBedrms', 'Longitude'),
#  ('HouseAge', 'AveRooms', 'Population', 'AveOccup'),
#  ('HouseAge', 'AveRooms', 'Population', 'Latitude'),
#  ('HouseAge', 'AveRooms', 'Population', 'Longitude'),
#  ('HouseAge', 'AveRooms', 'AveOccup', 'Latitude'),
#  ('HouseAge', 'AveRooms', 'AveOccup', 'Longitude'),
#  ('HouseAge', 'AveRooms', 'Latitude', 'Longitude'),
#  ('HouseAge', 'AveBedrms', 'Population', 'AveOccup'),
#  ('HouseAge', 'AveBedrms', 'Population', 'Latitude'),
#  ('HouseAge', 'AveBedrms', 'Population', 'Longitude'),
#  ('HouseAge', 'AveBedrms', 'AveOccup', 'Latitude'),
#  ('HouseAge', 'AveBedrms', 'AveOccup', 'Longitude'),
#  ('HouseAge', 'AveBedrms', 'Latitude', 'Longitude'),
#  ('HouseAge', 'Population', 'AveOccup', 'Latitude'),
#  ('HouseAge', 'Population', 'AveOccup', 'Longitude'),
#  ('HouseAge', 'Population', 'Latitude', 'Longitude'),
#  ('HouseAge', 'AveOccup', 'Latitude', 'Longitude'),
#  ('AveRooms', 'AveBedrms', 'Population', 'AveOccup'),
#  ('AveRooms', 'AveBedrms', 'Population', 'Latitude'),
#  ('AveRooms', 'AveBedrms', 'Population', 'Longitude'),
#  ('AveRooms', 'AveBedrms', 'AveOccup', 'Latitude'),
#  ('AveRooms', 'AveBedrms', 'AveOccup', 'Longitude'),
#  ('AveRooms', 'AveBedrms', 'Latitude', 'Longitude'),
#  ('AveRooms', 'Population', 'AveOccup', 'Latitude'),
#  ('AveRooms', 'Population', 'AveOccup', 'Longitude'),
#  ('AveRooms', 'Population', 'Latitude', 'Longitude'),
#  ('AveRooms', 'AveOccup', 'Latitude', 'Longitude'),
#  ('AveBedrms', 'Population', 'AveOccup', 'Latitude'),
#  ('AveBedrms', 'Population', 'AveOccup', 'Longitude'),
#  ('AveBedrms', 'Population', 'Latitude', 'Longitude'),
#  ('AveBedrms', 'AveOccup', 'Latitude', 'Longitude'),
#  ('Population', 'AveOccup', 'Latitude', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Latitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'Population', 'AveOccup'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'Population', 'Latitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'Population', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'AveOccup', 'Latitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'AveOccup', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'Latitude', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveBedrms', 'Population', 'AveOccup'),
#  ('MedInc', 'HouseAge', 'AveBedrms', 'Population', 'Latitude'),
#  ('MedInc', 'HouseAge', 'AveBedrms', 'Population', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveBedrms', 'AveOccup', 'Latitude'),
#  ('MedInc', 'HouseAge', 'AveBedrms', 'AveOccup', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveBedrms', 'Latitude', 'Longitude'),
#  ('MedInc', 'HouseAge', 'Population', 'AveOccup', 'Latitude'),
#  ('MedInc', 'HouseAge', 'Population', 'AveOccup', 'Longitude'),
#  ('MedInc', 'HouseAge', 'Population', 'Latitude', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveOccup', 'Latitude', 'Longitude'),
#  ('MedInc', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup'),
#  ('MedInc', 'AveRooms', 'AveBedrms', 'Population', 'Latitude'),
#  ('MedInc', 'AveRooms', 'AveBedrms', 'Population', 'Longitude'),
#  ('MedInc', 'AveRooms', 'AveBedrms', 'AveOccup', 'Latitude'),
#  ('MedInc', 'AveRooms', 'AveBedrms', 'AveOccup', 'Longitude'),
#  ('MedInc', 'AveRooms', 'AveBedrms', 'Latitude', 'Longitude'),
#  ('MedInc', 'AveRooms', 'Population', 'AveOccup', 'Latitude'),
#  ('MedInc', 'AveRooms', 'Population', 'AveOccup', 'Longitude'),
#  ('MedInc', 'AveRooms', 'Population', 'Latitude', 'Longitude'),
#  ('MedInc', 'AveRooms', 'AveOccup', 'Latitude', 'Longitude'),
#  ('MedInc', 'AveBedrms', 'Population', 'AveOccup', 'Latitude'),
#  ('MedInc', 'AveBedrms', 'Population', 'AveOccup', 'Longitude'),
#  ('MedInc', 'AveBedrms', 'Population', 'Latitude', 'Longitude'),
#  ('MedInc', 'AveBedrms', 'AveOccup', 'Latitude', 'Longitude'),
#  ('MedInc', 'Population', 'AveOccup', 'Latitude', 'Longitude'),
#  ('HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup'),
#  ('HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'Latitude'),
#  ('HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'Longitude'),
#  ('HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup', 'Latitude'),
#  ('HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup', 'Longitude'),
#  ('HouseAge', 'AveRooms', 'AveBedrms', 'Latitude', 'Longitude'),
#  ('HouseAge', 'AveRooms', 'Population', 'AveOccup', 'Latitude'),
#  ('HouseAge', 'AveRooms', 'Population', 'AveOccup', 'Longitude'),
#  ('HouseAge', 'AveRooms', 'Population', 'Latitude', 'Longitude'),
#  ('HouseAge', 'AveRooms', 'AveOccup', 'Latitude', 'Longitude'),
#  ('HouseAge', 'AveBedrms', 'Population', 'AveOccup', 'Latitude'),
#  ('HouseAge', 'AveBedrms', 'Population', 'AveOccup', 'Longitude'),
#  ('HouseAge', 'AveBedrms', 'Population', 'Latitude', 'Longitude'),
#  ('HouseAge', 'AveBedrms', 'AveOccup', 'Latitude', 'Longitude'),
#  ('HouseAge', 'Population', 'AveOccup', 'Latitude', 'Longitude'),
#  ('AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude'),
#  ('AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Longitude'),
#  ('AveRooms', 'AveBedrms', 'Population', 'Latitude', 'Longitude'),
#  ('AveRooms', 'AveBedrms', 'AveOccup', 'Latitude', 'Longitude'),
#  ('AveRooms', 'Population', 'AveOccup', 'Latitude', 'Longitude'),
#  ('AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'Latitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup', 'Latitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Latitude', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'Population', 'AveOccup', 'Latitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'Population', 'AveOccup', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'Population', 'Latitude', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveRooms', 'AveOccup', 'Latitude', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveBedrms', 'Population', 'AveOccup', 'Latitude'),
#  ('MedInc', 'HouseAge', 'AveBedrms', 'Population', 'AveOccup', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveBedrms', 'Population', 'Latitude', 'Longitude'),
#  ('MedInc', 'HouseAge', 'AveBedrms', 'AveOccup', 'Latitude', 'Longitude'),
#  ('MedInc', 'HouseAge', 'Population', 'AveOccup', 'Latitude', 'Longitude'),
#  ('MedInc', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude'),
#  ('MedInc', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Longitude'),
#  ('MedInc', 'AveRooms', 'AveBedrms', 'Population', 'Latitude', 'Longitude'),
#  ('MedInc', 'AveRooms', 'AveBedrms', 'AveOccup', 'Latitude', 'Longitude'),
#  ('MedInc', 'AveRooms', 'Population', 'AveOccup', 'Latitude', 'Longitude'),
#  ('MedInc', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude'),
#  ('HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude'),
#  ('HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Longitude'),
#  ('HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'Latitude', 'Longitude'),
#  ('HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup', 'Latitude', 'Longitude'),
#  ('HouseAge', 'AveRooms', 'Population', 'AveOccup', 'Latitude', 'Longitude'),
#  ('HouseAge', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude'),
#  ('AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude'),
#  ('MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude'),
#  ('MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Longitude'),
#  ('MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'Latitude',
#   'Longitude'),
#  ('MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'AveOccup',
#   'Latitude',
#   'Longitude'),
#  ('MedInc',
#   'HouseAge',
#   'AveRooms',
#   'Population',
#   'AveOccup',
#   'Latitude',
#   'Longitude'),
#  ('MedInc',
#   'HouseAge',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
#   'Longitude'),
#  ('MedInc',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
#   'Longitude'),
#  ('HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
#   'Longitude'),
#  ('MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
#   'Longitude')]

# %%
enumerate(combs)

# %%
linreg = LinearRegression()

R2_results = {}
for i,c in enumerate(combs):
    if (i % 250) == 0:
        print(i)
        
    subX = X[list(c)]
    R2_results[c] = np.mean(cross_val_score(linreg, subX, y))
# Out:
# 0
# 250

# %%
results = R2_results.items()
results = sorted(results, key=lambda x: x[1], reverse=True)

# %%
for i in range(5):
    print(results[i])
# Out:
# (('MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Latitude', 'Longitude'), 0.5549607879171521)
# (('MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'Latitude', 'Longitude'), 0.5540782576426884)
# (('MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup', 'Latitude', 'Longitude'), 0.5539063771113029)
# (('MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude'), 0.5530311140279561)
# (('MedInc', 'HouseAge', 'AveBedrms', 'Latitude', 'Longitude'), 0.5457551351572354)

# %% [markdown]
# ### 5.1 Can you explain what could be wrong with this approach?

# %%
# A:
